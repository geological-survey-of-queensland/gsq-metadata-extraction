# %%
import pandas as pd

# %%
data = pd.read_csv('SHUP 2D Files Training Data.csv')
data.head()
# Out:
#    Unique Record ID                                           FileName  \
# 0            129204  KINNOUL_BONNIE_DOON_80H-60_STACK_SDU10912TA_12...
# 1            129205  KINNOUL_BONNIE_DOON_80H-61_STACK_SDU10912TA_12...
# 2            129206  KINNOUL_BONNIE_DOON_80H-70_STACK_SDU10912TA_12...
# 3            129207        MARMADUA_80H-91_STACK_SDU10912TA_129207.sgy
# 4            129208        MARMADUA_80H-92_STACK_SDU10912TA_129208.sgy
#
#   Original_FileName  SurveyNum           SurveyName LineName SurveyType  \
# 0        80H-60.sgy      80022  KINNOUL-BONNIE DOON   80H-60     LAND2D
# 1        80H-61.sgy      80022  KINNOUL-BONNIE DOON   80H-61     LAND2D
# 2        80H-70.sgy      80022  KINNOUL-BONNIE DOON   80H-70     LAND2D
# 3        80H-91.sgy      80025             MARMADUA   80H-91     LAND2D
# 4        80H-92.sgy      80025             MARMADUA   80H-92     LAND2D
#
#   PrimaryDataType SecondaryDataType TertiaryDataType  ... File_Range  \
# ...

# %%
data.dtypes
# Out:
# Unique Record ID      int64
# FileName             object
# Original_FileName    object
# SurveyNum             int64
# SurveyName           object
# LineName             object
# SurveyType           object
# PrimaryDataType      object
# SecondaryDataType    object
# TertiaryDataType     object
# Quaternary           object
# File_Range           object
# First_SP_CDP         object
# Last_SP_CDP          object
# CompletionYear        int64
# TenureType           object
# Operator Name        object
# GSQBarcode           object
# EnergySource         object
# LookupDOSFilePath    object
# Source Of Data       object
# dtype: object

# %%
categorical = [
    'SurveyType',
    'PrimaryDataType',
    'SecondaryDataType',
    'TertiaryDataType',
    'Quaternary',
    'TenureType',
    'EnergySource',
    'Source Of Data',
]

for c in categorical:
    u = data[c].unique()
    print(c, len(u), u, sep='    ', end='\n\n')
# Out:
# SurveyType    1    ['LAND2D']
#
# PrimaryDataType    1    ['PROCESSED_SEGY']
#
# SecondaryDataType    68    ['STACK' 'FINAL_MIGRATED' 'FINAL_STACK' 'RAW_MIGRATED' 'PSTM' 'RAW_STACK'
#  'FINAL_FILTERED' 'FINAL_FILTERED_MIGRATED' 'FILTERED_MIGRATION'
#  'FILTERED' 'FINAL' 'FINAL_FILTERED_SCALED' 'FILTERED_SCALED'
#  'FILTERED_SCALED_DMO' 'FILTERED_MIGRATED_SCALED' 'RAW_DMO_STACK' 'PSD'
#  'MIGRATED' 'FINAL_UNFILTERED' 'POST_STACK' 'REFLECTION_SECTION'
#  'UNFILTERED_FINAL' 'UNFILTERED_STACK' 'UNFILTERED_MIGRATED' 'FINAL_RAW'
#  'OUT_OUT_MIGRATED' 'PROCESSED' 'FILTERED_INTERPOLATED_MIGRATION'
#  'RAW_FINAL' 'FILTERED_INTERPOLATED_STACK' 'FX_DECON_STACK' 'GAIN_STACK'
#  'UNGAIN_STACK' 'UNGAIN_MIGRATED_STACK' 'CORRELATED_STACK'
#  'PSD_DECON_STACK' 'PROCESSED_CORRELATED_DIVERSITY_STACK' 'FILTERED_DMO'
#  'FILTERED_MIGRATION_DMO' 'MERGED_STACK' 'RESIDUAL_STACK'
#  'STRUCTURAL_STACK' 'WAVE_MIGRATION' 'PROCESSED_DBS_CDP'
#  'FILTERED_SCALED_MIGRATED' 'MIGRATION_ANTI_DEPHASE'
# ...
